# %% [markdown]
# # PACC Plot Gallery

# %%
import sys
import numpy as np
import sacc
import yaml
import pacc
import pandas as pd

# %% [markdown]
# ## DES Y1 Real Space

# %%
s = sacc.Sacc.load_fits("../firecrown/examples/des_y1_3x2pt/des_y1_3x2pt_sacc_data.fits")

# %%
cle = pacc.ClsEnsemble(s, label="DES Y1 Xi")

# %%
pacc.plot_cls([cle], cle.pairs)

# %% [markdown]
# ## CosmoDC2

# %%
s = sacc.Sacc.load_fits("/home/jaimerz/Documents/UCL/3x2_analytical/data/CosmoDC2/summary_statistics_fourier_tjpcov.sacc")
y = yaml.load(open("/home/jaimerz/Documents/UCL/3x2_analytical/data/CosmoDC2/gcgc_gcwl_wlwl.yml"), Loader=yaml.FullLoader)

# %%
cle = pacc.ClsEnsemble(s, y, label="CosmoDC2 - data")

# %%
t_spec = pd.read_csv("/home/jaimerz/Documents/UCL/3x2_analytical/CosmoDC2_theory_spec.csv")
t_photo_bpz = pd.read_csv("/home/jaimerz/Documents/UCL/3x2_analytical/CosmoDC2_theory_photo_bpz.csv")
t_photo_flexzboost = pd.read_csv("/home/jaimerz/Documents/UCL/3x2_analytical/CosmoDC2_theory_photo_flexzboost.csv")

# %%
t_spec_arr = np.array(t_spec).transpose()[0]
t_photo_bpz_arr = np.array(t_photo_bpz).transpose()[0]
t_photo_flexzboost_arr = np.array(t_photo_flexzboost).transpose()[0]

# %%
t_cle_spec = pacc.ClTheoryEnsemble(cle, t_spec_arr, label='CosmoDC theory - spec')
t_cle_photo_bpz = pacc.ClTheoryEnsemble(cle, t_photo_bpz_arr, label='CosmoDC theory - photo BPZ')
t_cle_photo_flexzboost = pacc.ClTheoryEnsemble(cle, t_photo_flexzboost_arr, label='CosmoDC theory - photo FlexZBoost')

# %%
pacc.plot_cls([cle, t_cle_spec, t_cle_photo_flexzboost], cle.pairs)

# %% [markdown]
# ## HSC

# %%
s = sacc.Sacc.load_fits("/home/jaimerz/Documents/UCL/3x2_analytical/data/HSC/HSC.sacc")
y = yaml.load(open("/home/jaimerz/Documents/UCL/3x2_analytical/data/HSC/gcgc_gcwl_wlwl.yml"), Loader=yaml.FullLoader)

# %%
theory = np.array([3.5203537958866914e-10, 6.236715584552095e-10, 2.27449505321058e-10, 1.1207110413149376e-10, 5.127812806837769e-11, 2.390280855332014e-11, 1.3321883488952617e-11, 6.728605158600022e-12, 3.3540642937723103e-12, 1.938150487311007e-12, 1.318757807959591e-9, 4.985720794957244e-10, 2.5026847424042546e-10, 8.176863586644433e-10, 3.0370016947277067e-10, 1.5116715882824373e-10, 6.982493406479337e-11, 3.280607226251696e-11, 1.8381736879053758e-11, 9.336249785447053e-12, 4.678136162283137e-12, 2.713278427004254e-12, 1.9169357184536456e-9, 7.41948115628769e-10, 3.770405232027058e-10, 1.7733553923840218e-10, 8.452228427164687e-11, 4.781067980273078e-11, 2.452522627468396e-11, 1.2393877832340354e-11, 7.232081537684352e-12, 3.1907652998305693e-9, 1.2790312350443527e-9, 6.618565749785171e-10, 3.164145792225634e-10, 9.514286165983992e-10, 3.
 6.161300060789464e-9, 3.531634897936512e-9, 3.359479108015566e-10, 2.2294556197523884e-10, 1.4838603811155918e-10, 1.07064094518817e-10, 7.148658887973563e-11, 4.6025251035414575e-11, 5.075321692317383e-10, 3.3733472994622224e-10, 2.274123714627168e-10, 1.665918486515366e-10, 1.1364129678507795e-10, 7.492706368627555e-11, 9.323429669994696e-10, 6.139893689283214e-10, 4.1698583854645853e-10, 3.1007609959833327e-10, 2.1686084703128513e-10, 1.4738898257679872e-10, 6.163089601424803e-10, 4.066603740432591e-10, 2.737765490768674e-10, 2.0112331267251472e-10, 1.3815512503122507e-10, 9.204578478698555e-11, 1.21367607593882e-9, 7.913979345601606e-10, 5.358735899325852e-10, 3.994527258977109e-10, 2.813948460966452e-10, 1.933768044247172e-10, 1.7772671787561117e-9, 1.1376345567916627e-9, 7.624863475019029e-10, 5.679446059656624e-10, 4.0268397337751157e-10, 2.804403361793722e-10, 6.769832177118375e-10, 4.444122302898887e-10, 2.984525456277156e-10, 2.1927111649636196e-10, 1.509465989448217e-10, 1.0099102314332456e-10, 1.3445634126918182e-9, 8.733883665289154e-10, 5.90445794196325e-10, 4.403193638013556e-10, 3.1083209628287036e-10, 2.1435637409152835e-10, 2.0826490308435196e-9, 1.3228793671703214e-9, 8.819255858225033e-10, 6.558977377146971e-10, 4.6556333297098997e-10, 3.2551496498716235e-10, 2.527397382850997e-9, 1.5893489593545826e-9, 1.0513019498681682e-9, 7.795089283706632e-10, 5.533859930929443e-10, 3.884136656950579e-10])

# %%
cle = pacc.ClsEnsemble(s,y, label='HSC')

# %%
t_cle = pacc.ClTheoryEnsemble(cle, theory, label='HSC theory')

# %%
wanted_pairs = [['lens_0', 'lens_0'],
                ['lens_1', 'lens_1'],
                ['lens_2', 'lens_2'],
                ['lens_3', 'lens_3']]

# %%
clse = pacc.ClSubSemble(cle, wanted_pairs)
clse.cov
sig = np.sqrt(np.diag(clse.cov))
corr = clse.cov / np.outer(sig, sig)

# %%
pacc.plot_cls([cle, t_cle], wanted_pairs)

# %%
pacc.plot_cls([cle, t_cle], cle.pairs)

# %%
pacc.plot_cov(cle, wanted_pairs, logscale=True)
# Out:
# /home/jaimerz/Documents/UCL/pacc/pacc/__init__.py:83: RuntimeWarning: divide by zero encountered in log10
#   cov = np.log10(abs(cov))

# %%
pacc.plot_corr(cle, wanted_pairs, logscale=False)

# %% [markdown]
# ## DES Y1

# %%
s = sacc.Sacc.load_fits("/home/jaimerz/Documents/PhD/LimberJack.jl/data/FD/cls_FD_covG.fits")
y = yaml.load(open("/home/jaimerz/Documents/PhD/LimberJack.jl/data/DESY1/gcgc_gcwl_wlwl.yml"), Loader=yaml.FullLoader)

# %%
cle = pacc.ClsEnsemble(s,y)

# %%
pacc.plot_cls([cle], cle.pairs)

# %%
pacc.plot_cov(cle, cle.pairs, logscale=True)
# Out:
# /home/jaimerz/Documents/UCL/pacc/pacc/__init__.py:83: RuntimeWarning: divide by zero encountered in log10
#   cov = np.log10(abs(cov))

# %%
pacc.plot_corr(cle, cle.pairs, logscale=False)
