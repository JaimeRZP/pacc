# %% [markdown]
# # PACC Plot Gallery

# %%
import sys
import numpy as np
import sacc
import yaml
import pacc
#import pandas as pd

# %% [markdown]
# ## CosmoDC2

# %%
s = sacc.Sacc.load_fits("/home/jaimerzp/Documents/UCL/3x2_analytical/data/CosmoDC2/summary_statistics_fourier_tjpcov.sacc")

# %%
cle = pacc.ClsEnsemble(s, label="CosmoDC2 - data")

# %%
pacc.plot_cls([[cle]], cle.pairs);
